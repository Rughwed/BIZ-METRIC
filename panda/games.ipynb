# %%
import numpy as np

# %%
import pandas as pd

# %%
fr = pd.read_csv('FRvideos.csv')
ca= pd.read_csv('CAvideos.csv')
de = pd.read_csv('DEvideos.csv')
us = pd.read_csv('USvideos.csv')
gb = pd.read_csv('GBvideos.csv',on_bad_lines='skip')

# %%
fr.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
ca.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
de.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
us.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
gb.columns
# Out:
# Index(['video_id', 'title', 'channel_title', 'category_id', 'tags', 'views',
#        'likes', 'dislikes', 'comment_total', 'thumbnail_link', 'date'],
#       dtype='object')

# %%
pd.concat([fr,gb,de,us,ca],axis=0)
# Out:
#          video_id trending_date  \
# 0     Ro6eob0LrCY      17.14.11
# 1     Yo84eqYwP98      17.14.11
# 2     ceqntSXE-10      17.14.11
# 3     WuTFI5qftCE      17.14.11
# 4     ee6OFs8TdEg      17.14.11
# ...           ...           ...
# 2194  3fFBEPZeYY0      17.24.11
# 2195  qaZd--LEMyo      17.24.11
# 2196  Ja8sm19k0e0      17.24.11
# 2197  y_XvYHi42hs      17.24.11
# 2198  Ufqs0mxfqRI      17.24.11
#
#                                                   title        channel_title  \
# 0              Malika LePen : Femme de Gauche - Trailer  Le Raptor Dissident
# 1     LA PIRE PARTIE ft Le Rire Jaune, Pierre Croce,...              Le Labo
# 2     DESSINS ANIMÉS FRANÇAIS VS RUSSES 2 - Daniil...      Daniil le Russe
# 3                       PAPY GRENIER - METAL GEAR SOLID    Joueur Du Grenier
# 4     QUI SAUTERA LE PLUS HAUT ? (VÉLO SKATE ROLLER ...    Aurelien Fontenoy
# ...                                                 ...                  ...
# ...

# %%
fr.merge(ca,on='trending_date')
# Out:
#          video_id_x trending_date  \
# 0       Ro6eob0LrCY      17.14.11
# 1       Ro6eob0LrCY      17.14.11
# 2       Ro6eob0LrCY      17.14.11
# 3       Ro6eob0LrCY      17.14.11
# 4       Ro6eob0LrCY      17.14.11
# ...             ...           ...
# 439595  qXn8NXDox1A      17.24.11
# 439596  qXn8NXDox1A      17.24.11
# 439597  qXn8NXDox1A      17.24.11
# 439598  qXn8NXDox1A      17.24.11
# 439599  qXn8NXDox1A      17.24.11
#
#                                                   title_x  \
# 0                Malika LePen : Femme de Gauche - Trailer
# 1                Malika LePen : Femme de Gauche - Trailer
# 2                Malika LePen : Femme de Gauche - Trailer
# 3                Malika LePen : Femme de Gauche - Trailer
# 4                Malika LePen : Femme de Gauche - Trailer
# ...                                                   ...
# 439595  Loup d'Abyssinie VS rat-taupe géant - ZAPPING...
# 439596  Loup d'Abyssinie VS rat-taupe géant - ZAPPING...
# ...

# %%
caj = pd.read_json('CA_category_id.json')
frj = pd.read_json('FR_category_id.json')
usj = pd.read_json('US_category_id.json')
dej = pd.read_json('DE_category_id.json')
gbj = pd.read_json('GB_category_id.json')

# %%
caj
# Out:
#                                  kind  \
# 0   youtube#videoCategoryListResponse
# 1   youtube#videoCategoryListResponse
# 2   youtube#videoCategoryListResponse
# 3   youtube#videoCategoryListResponse
# 4   youtube#videoCategoryListResponse
# 5   youtube#videoCategoryListResponse
# 6   youtube#videoCategoryListResponse
# 7   youtube#videoCategoryListResponse
# 8   youtube#videoCategoryListResponse
# 9   youtube#videoCategoryListResponse
# 10  youtube#videoCategoryListResponse
# 11  youtube#videoCategoryListResponse
# 12  youtube#videoCategoryListResponse
# 13  youtube#videoCategoryListResponse
# 14  youtube#videoCategoryListResponse
# 15  youtube#videoCategoryListResponse
# 16  youtube#videoCategoryListResponse
# 17  youtube#videoCategoryListResponse
# 18  youtube#videoCategoryListResponse
# 19  youtube#videoCategoryListResponse
# 20  youtube#videoCategoryListResponse
# 21  youtube#videoCategoryListResponse
# 22  youtube#videoCategoryListResponse
# ...

# %%
a =caj["items"]

# %%
a
# Out:
# 0     {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 1     {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 2     {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 3     {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 4     {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 5     {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 6     {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 7     {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 8     {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 9     {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 10    {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 11    {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 12    {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 13    {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 14    {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 15    {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 16    {'kind': 'youtube#videoCategory', 'etag': '"ld...
# ...

# %%
for i in range(20):
    print(f"{caj["items"][i]["snippet"]["title"]:30}{caj["items"][i]["snippet"]["channelId"]}")
# Out:
# Film & Animation              UCBR8-60-B28hp2BmDPdntcQ
# Autos & Vehicles              UCBR8-60-B28hp2BmDPdntcQ
# Music                         UCBR8-60-B28hp2BmDPdntcQ
# Pets & Animals                UCBR8-60-B28hp2BmDPdntcQ
# Sports                        UCBR8-60-B28hp2BmDPdntcQ
# Short Movies                  UCBR8-60-B28hp2BmDPdntcQ
# Travel & Events               UCBR8-60-B28hp2BmDPdntcQ
# Gaming                        UCBR8-60-B28hp2BmDPdntcQ
# Videoblogging                 UCBR8-60-B28hp2BmDPdntcQ
# People & Blogs                UCBR8-60-B28hp2BmDPdntcQ
# Comedy                        UCBR8-60-B28hp2BmDPdntcQ
# Entertainment                 UCBR8-60-B28hp2BmDPdntcQ
# News & Politics               UCBR8-60-B28hp2BmDPdntcQ
# Howto & Style                 UCBR8-60-B28hp2BmDPdntcQ
# Education                     UCBR8-60-B28hp2BmDPdntcQ
# Science & Technology          UCBR8-60-B28hp2BmDPdntcQ
# Movies                        UCBR8-60-B28hp2BmDPdntcQ
# ...

# %%
ca["channel_title"].unique()
# Out:
# array(['EminemVEVO', 'iDubbbzTV', 'Rudy Mancuso', 'nigahiga',
#        'Ed Sheeran', 'DramaAlert', 'VanossGaming', 'CaseyNeistat',
#        'Logan Paul Vlogs', 'Sheikh Musa', '21 Savage', 'Troom Troom',
#        '大劇獨播', 'Speed Records', 'FBE', 'BuzzFeedBlue', 'NELK',
#        'The Graham Norton Show', 'Rooster Teeth', 'Lokdhun Punjabi',
#        'CrazyRussianHacker', 'Good Mythical Morning', 'The Q',
#        'Jake Paul', 'REACT', 'HigaTV', 'REKT', 'Lama Faché', 'Philly D',
#        'Hey Yolo', 'FaZe Adapt', 'Good Mythical MORE', 'BuzzFeedVideo',
#        'Joueur Du Grenier', '麻辣变形计 HOT GIRL', 'MSNBC',
#        'Achievement Hunter', 'H3 Podcast', 'Sugar Pine 7', 'Danny Duncan',
#        'Mcfly & Carlito', 'Canada Soccer', 'Soul Machines', 'CNN',
#        'jeffreestar', 'Real Time with Bill Maher', 'Michael McCrudden',
#        'SteveDangle', 'SQUEEZIE', 'T-Series', '蒙面唱将猜猜猜2重磅归来',
#        "Le Jeu, C'est Sérieux", 'DUTERTE NEWS REPORT', 'The king of DIY',
# ...
