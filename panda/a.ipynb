# %%
import pandas as pd

# %% [markdown]
# # 1. Read superstore data

# %%
read = pd.read_excel('Superstore.xls',engine='xlrd')

# %% [markdown]
# # 2.find the index of the data

# %%
a = read.index
a
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %% [markdown]
# # 3.find the columns of the data

# %%
c = read.columns
c
# Out:
# Index(['no', 'order _id', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# # 4. if columns name is having space then remove the
# # space and rename the column. find the various ways
# # to rename the column

# %%
x = read.columns.str.replace(' ','_')

# %%
x
# Out:
# Index(['no', 'order__id', 'Order_Date', 'Ship_Date', 'Ship_Mode',
#        'Customer_ID', 'Customer_Name', 'Segment', 'Country', 'City', 'State',
#        'Postal_Code', 'Region', 'Product_ID', 'Category', 'Sub-Category',
#        'Product_Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
read.columns = x

# %%
read.columns
# Out:
# Index(['no', 'order__id', 'Order_Date', 'Ship_Date', 'Ship_Mode',
#        'Customer_ID', 'Customer_Name', 'Segment', 'Country', 'City', 'State',
#        'Postal_Code', 'Region', 'Product_ID', 'Category', 'Sub-Category',
#        'Product_Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# # 5. display first 40 records

# %%
read.head(40)
# Out:
#       no       order__id Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0    NaN             NaN 2016-11-08 2016-11-11    Second Class    CG-12520
# 1    2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2    3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3    4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4    5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5    6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6    7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7    8.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8    9.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9   10.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 10  11.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# ...

# %% [markdown]
# # 6. display last 15 records from the data

# %%
read.tail(15)
# Out:
#           no       order__id Order_Date  Ship_Date       Ship_Mode  \
# 9979  9980.0  US-2016-103674 2016-12-06 2016-12-10  Standard Class
# 9980  9981.0  US-2015-151435 2015-09-06 2015-09-09    Second Class
# 9981  9982.0  CA-2017-163566 2017-08-03 2017-08-06     First Class
# 9982  9983.0  US-2016-157728 2016-09-22 2016-09-28  Standard Class
# 9983  9984.0  US-2016-157728 2016-09-22 2016-09-28  Standard Class
# 9984  9985.0  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9985  9986.0  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9986  9987.0  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# 9987  9988.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9988  9989.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9989  9990.0  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990  9991.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991  9992.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# ...

# %% [markdown]
# # 7. change the setting to display minimum 30 rows for
# # given data

# %%
pd.options.display.min_rows= 30

# %% [markdown]
# # 8. change the display setting to minimum row as 3

# %%
pd.options.display.min_rows= 3

# %% [markdown]
# # 9.take a slice from the dataframe based on the
# # columns city, state, region, profit columns

# %%
csr = read.loc(axis=1)['City','State','Region','Profit']
csr
# Out:
#              City       State Region   Profit
# 0       Henderson    Kentucky  South  41.9136
# ...           ...         ...    ...      ...
# 9993  Westminster  California   West  72.9480
#
# [9994 rows x 4 columns]

# %%
graph = csr.groupby("Region")["Profit"].mean()
dg = pd.DataFrame(graph)
dg
# Out:
#             Profit
# Region
# Central  17.092709
# East     32.135808
# South    28.857673
# West     33.849032

# %%
import matplotlib.pyplot as pl

# %%
pl.bar(dg.index,dg["Profit"],color='c')
pl.xlabel("Region")
pl.ylabel("Average Profit")
pl.title("Average Profit by Region")
# Out:
# Text(0.5, 1.0, 'Average Profit by Region')

# %%
dg["Region"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Region'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 dg["Region"]
#
# ...

# %%
import matplotlib.pyplot as pl

# %%
pl.bar(dg["Region"],dg["Profit"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Region'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 1
# ...

# %% [markdown]
# # 10. Take a slice based on data available at 1000 to
#  # 1500 position and columns from 4 to 8

# %%
read.iloc[1000:1501,4:9]
# Out:
#            Ship_Mode Customer_ID  Customer_Name      Segment        Country
# 1000  Standard Class    FM-14290   Frank Merwin  Home Office  United States
# ...              ...         ...            ...          ...            ...
# 1500  Standard Class    NG-18430  Nathan Gelder     Consumer  United States
#
# [501 rows x 5 columns]

# %% [markdown]
# # 11. Rename the index starts from 1900 to end of
#  # the data

# %%
read.reset_index()
# Out:
#       index      no       order__id Order_Date  Ship_Date     Ship_Mode  \
# 0         0     NaN             NaN 2016-11-08 2016-11-11  Second Class
# ...     ...     ...             ...        ...        ...           ...
# 9993   9993  9994.0  CA-2017-119914 2017-05-04 2017-05-09  Second Class
#
#      Customer_ID Customer_Name   Segment        Country  ... Postal_Code  \
# 0       CG-12520   Claire Gute  Consumer  United States  ...       42420
# ...          ...           ...       ...            ...  ...         ...
# 9993    CC-12220  Chris Cortes  Consumer  United States  ...       92683
#
#      Region       Product_ID         Category Sub-Category  \
# 0     South  FUR-BO-10001798        Furniture    Bookcases
# ...     ...              ...              ...          ...
# 9993   West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product_Name   Sales Quantity  \
# ...

# %%
a = 1900
for i in read.index:
    a +=1
a
# Out:
# 11894

# %%
read.index = range(1900,a)

# %%
read.reset_index()
# Out:
#       index      no       order__id Order_Date  Ship_Date     Ship_Mode  \
# 0      1900     NaN             NaN 2016-11-08 2016-11-11  Second Class
# ...     ...     ...             ...        ...        ...           ...
# 9993  11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09  Second Class
#
#      Customer_ID Customer_Name   Segment        Country  ... Postal_Code  \
# 0       CG-12520   Claire Gute  Consumer  United States  ...       42420
# ...          ...           ...       ...            ...  ...         ...
# 9993    CC-12220  Chris Cortes  Consumer  United States  ...       92683
#
#      Region       Product_ID         Category Sub-Category  \
# 0     South  FUR-BO-10001798        Furniture    Bookcases
# ...     ...              ...              ...          ...
# 9993   West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product_Name   Sales Quantity  \
# ...

# %% [markdown]
# # 12. Take a slice from data based on index having
# # name as 1920 , 1940, 1945, 1980, and columns as
# # profit, state, category, sub-category, region

# %%
read.loc[[1901,1940,1945,1980],['Profit','State','Category','Sub-Category','Region']]
# Out:
#         Profit      State         Category Sub-Category   Region
# 1901  219.5820   Kentucky        Furniture       Chairs    South
# 1940   41.7564      Texas       Technology       Phones  Central
# 1945    8.2062  Minnesota  Office Supplies      Binders  Central
# 1980    8.0352    Alabama  Office Supplies      Binders    South

# %% [markdown]
# # 13. Check the data type of columns

# %%
type(read.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
read.loc[:,:].dtypes
# Out:
# no                      float64
# order__id                object
# Order_Date       datetime64[ns]
# Ship_Date        datetime64[ns]
# Ship_Mode                object
# Customer_ID              object
# Customer_Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal_Code               int64
# Region                   object
# Product_ID               object
# Category                 object
# Sub-Category             object
# Product_Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %% [markdown]
# # 14. Find out the record for the month of jun-2014

# %%
import datetime as dt

# %%
a = dt.datetime.strptime('2014-06','%Y-%m')

# %%
a.month
# Out:
# 6

# %%
a.year
# Out:
# 2014

# %%
read[(read["Order_Date"]>='2014-06-01') & (read["Order_Date"]<='2014-06-30')]
# Out:
#            no       order__id Order_Date  Ship_Date       Ship_Mode  \
# 1905      6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...       ...             ...        ...        ...             ...
# 11796  9897.0  CA-2014-156342 2014-06-17 2014-06-20    Second Class
#
#       Customer_ID      Customer_Name   Segment        Country         City  \
# 1905     BH-11710    Brosina Hoffman  Consumer  United States  Los Angeles
# ...           ...                ...       ...            ...          ...
# 11796    JF-15415  Jennifer Ferguson  Consumer  United States      Chicago
#
#        ... Postal_Code   Region       Product_ID         Category  \
# 1905   ...       90032     West  FUR-FU-10001487        Furniture
# ...    ...         ...      ...              ...              ...
# 11796  ...       60653  Central  OFF-PA-10001725  Office Supplies
#
#       Sub-Category                                       Product_Name   Sales  \
# ...

# %% [markdown]
# # 15. Calculate month wise average of profit.

# %%
read.groupby([read['Order_Date'].dt.month==9])["Profit"].mean()
# Out:
# Order_Date
# False    28.97916
# True     26.65038
# Name: Profit, dtype: float64

# %% [markdown]
# # 16. Create the new data frame for California

# %%
new= pd.DataFrame(read[read['State']=='California'])

# %%
new
# Out:
#            no       order__id Order_Date  Ship_Date     Ship_Mode Customer_ID  \
# 1902      3.0  CA-2016-138688 2016-06-12 2016-06-16  Second Class    DV-13045
# ...       ...             ...        ...        ...           ...         ...
# 11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09  Second Class    CC-12220
#
#          Customer_Name    Segment        Country         City  ...  \
# 1902   Darrin Van Huff  Corporate  United States  Los Angeles  ...
# ...                ...        ...            ...          ...  ...
# 11893     Chris Cortes   Consumer  United States  Westminster  ...
#
#       Postal_Code  Region       Product_ID         Category Sub-Category  \
# 1902        90036    West  OFF-LA-10000240  Office Supplies       Labels
# ...           ...     ...              ...              ...          ...
# 11893       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                             Product_Name   Sales  Quantity  \
# ...

# %% [markdown]
# # 18. Find state wise sum of sales.

# %%
read.groupby(read['State'])['Sales'].sum()
# Out:
# State
# Alabama                  19510.6400
# Arizona                  35282.0010
# Arkansas                 11678.1300
# California              457687.6315
# Colorado                 32108.1180
# Connecticut              13384.3570
# Delaware                 27451.0690
# District of Columbia      2865.0200
# Florida                  89473.7080
# Georgia                  49095.8400
# Idaho                     4382.4860
# Illinois                 80166.1010
# Indiana                  53555.3600
# Iowa                      4579.7600
# Kansas                    2914.3100
# Kentucky                 36591.7500
# Louisiana                 9217.0300
# Maine                     1270.5300
# Maryland                 23705.5230
# Massachusetts            28634.4340
# Michigan                 76269.6140
# Minnesota                29863.1500
# Mississippi              10771.3400
# Missouri                 22205.1500
# Montana                   5589.3520
# Nebraska                  7464.9300
# ...

# %% [markdown]
# # 17. Find sum of sales

# %%
read["Sales"].sum()
# Out:
# 2297200.8603000003

# %% [markdown]
# # 19. Find month wise sum of sales

# %%
read.groupby(read['Order_Date'].dt.month)['Sales'].sum()
# Out:
# Order_Date
# 1      94924.8356
# 2      59751.2514
# 3     205005.4888
# 4     137762.1286
# 5     155028.8117
# 6     152718.6793
# 7     147238.0970
# 8     159044.0630
# 9     307649.9457
# 10    200322.9847
# 11    352461.0710
# 12    325293.5035
# Name: Sales, dtype: float64

# %% [markdown]
# # 20. Find country wise and city wise average profit

# %%
read.groupby(['Country','City'])['Profit'].mean()
# Out:
# Country        City
# United States  Aberdeen      6.630000
#                               ...
#                Yuma       -116.497725
# Name: Profit, Length: 531, dtype: float64

# %% [markdown]
# # 21. Calculate region wise average profit.

# %%
read.groupby('Region')["Profit"].mean()
# Out:
# Region
# Central    17.092709
# East       32.135808
# South      28.857673
# West       33.849032
# Name: Profit, dtype: float64

# %% [markdown]
# # 22. Find the ship mode which is more profitable.

# %%
a = pd.DataFrame(read.groupby('Ship_Mode')['Profit'].max())

# %%
a.reset_index()
# Out:
#         Ship_Mode     Profit
# 0     First Class  6719.9808
# 1        Same Day  2229.0240
# 2    Second Class  2799.9840
# 3  Standard Class  8399.9760

# %%
b = a.sort_values("Profit").tail(1)

# %%
b
# Out:
#                   Profit
# Ship_Mode
# Standard Class  8399.976

# %% [markdown]
# # 23. Create a new data frame where loss is recorded

# %%
new = read[read["Profit"]<0]

# %%
new
# Out:
#            no       order__id Order_Date  Ship_Date       Ship_Mode  \
# 1903      4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...       ...             ...        ...        ...             ...
# 11862  9963.0  CA-2015-168088 2015-03-19 2015-03-22     First Class
#
#       Customer_ID     Customer_Name      Segment        Country  \
# 1903     SO-20335    Sean O'Donnell     Consumer  United States
# ...           ...               ...          ...            ...
# 11862    CM-12655  Corinna Mitchell  Home Office  United States
#
#                   City  ... Postal_Code   Region       Product_ID   Category  \
# 1903   Fort Lauderdale  ...       33311    South  FUR-TA-10000577  Furniture
# ...                ...  ...         ...      ...              ...        ...
# 11862          Houston  ...       77041  Central  FUR-BO-10004218  Furniture
#
#       Sub-Category                                       Product_Name  \
# ...

# %% [markdown]
# # 24. Find category wise sub category wise sales

# %%
read.groupby(["Category","Sub-Category"])["Sales"].sum()
# Out:
# Category         Sub-Category
# Furniture        Bookcases       114879.9963
#                  Chairs          328449.1030
#                  Furnishings      91705.1640
#                  Tables          206965.5320
# Office Supplies  Appliances      107532.1610
#                  Art              27118.7920
#                  Binders         203412.7330
#                  Envelopes        16476.4020
#                  Fasteners         3024.2800
#                  Labels           12486.3120
#                  Paper            78479.2060
#                  Storage         223843.6080
#                  Supplies         46673.5380
# Technology       Accessories     167380.3180
#                  Copiers         149528.0300
#                  Machines        189238.6310
#                  Phones          330007.0540
# Name: Sales, dtype: float64

# %% [markdown]
# # 25. Create a data frame for record where discount is 0

# %%
read[read["Discount"]==0]
# Out:
#            no       order__id Order_Date  Ship_Date     Ship_Mode Customer_ID  \
# 1900      NaN             NaN 2016-11-08 2016-11-11  Second Class    CG-12520
# ...       ...             ...        ...        ...           ...         ...
# 11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09  Second Class    CC-12220
#
#       Customer_Name   Segment        Country         City  ... Postal_Code  \
# 1900    Claire Gute  Consumer  United States    Henderson  ...       42420
# ...             ...       ...            ...          ...  ...         ...
# 11893  Chris Cortes  Consumer  United States  Westminster  ...       92683
#
#        Region       Product_ID         Category Sub-Category  \
# 1900    South  FUR-BO-10001798        Furniture    Bookcases
# ...       ...              ...              ...          ...
# 11893    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                             Product_Name   Sales  Quantity  \
# ...

# %% [markdown]
# # 26.Create a data frame where order date and ship date both are in JAN-2014

# %%
read[(read["Order_Date"].dt.month==1)&(read["Order_Date"].dt.year==2014) & (read["Ship_Date"].dt.month==1)&(read["Ship_Date"].dt.year==2014)  ]
# Out:
#            no       order__id Order_Date  Ship_Date       Ship_Mode  \
# 2492    593.0  CA-2014-135405 2014-01-09 2014-01-13  Standard Class
# ...       ...             ...        ...        ...             ...
# 11889  9990.0  CA-2014-110422 2014-01-21 2014-01-23    Second Class
#
#       Customer_ID     Customer_Name   Segment        Country    City  ...  \
# 2492     MS-17830     Melanie Seite  Consumer  United States  Laredo  ...
# ...           ...               ...       ...            ...     ...  ...
# 11889    TB-21400  Tom Boeckenhauer  Consumer  United States   Miami  ...
#
#       Postal_Code   Region       Product_ID         Category Sub-Category  \
# 2492        78041  Central  OFF-AR-10004078  Office Supplies          Art
# ...           ...      ...              ...              ...          ...
# 11889       33180    South  FUR-FU-10001889        Furniture  Furnishings
#
#                  Product_Name   Sales  Quantity  Discount  Profit
# ...

# %% [markdown]
# # 27.Find records having profit for consumer segment.

# %%
read[(read["Segment"]=="Consumer" ) & (read["Profit"]>0)]
# Out:
#            no       order__id Order_Date  Ship_Date     Ship_Mode Customer_ID  \
# 1900      NaN             NaN 2016-11-08 2016-11-11  Second Class    CG-12520
# ...       ...             ...        ...        ...           ...         ...
# 11893  9994.0  CA-2017-119914 2017-05-04 2017-05-09  Second Class    CC-12220
#
#       Customer_Name   Segment        Country         City  ... Postal_Code  \
# 1900    Claire Gute  Consumer  United States    Henderson  ...       42420
# ...             ...       ...            ...          ...  ...         ...
# 11893  Chris Cortes  Consumer  United States  Westminster  ...       92683
#
#        Region       Product_ID         Category Sub-Category  \
# 1900    South  FUR-BO-10001798        Furniture    Bookcases
# ...       ...              ...              ...          ...
# 11893    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                             Product_Name   Sales  Quantity  \
# ...

# %% [markdown]
# # 28.Generate new data frame for every state (hint: dynamic variable creation)

# %%
pd.options.display.max_rows=5

# %%
states = read["State"].unique()
states
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %%
for i in ['Kentucky','California']:
    globals[i] = pd.DataFrame(read[read["State"]==i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 2
#       1 for i in ['Kentucky','California']:
# ----> 2     globals[i] = pd.DataFrame(read[read["State"]==i])
#
# TypeError: 'builtin_function_or_method' object does not support item assignment

# %%
globals()["Kentucky"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 globals()["Kentucky"]
#
# KeyError: 'Kentucky'

# %% [markdown]
# # 29.Generate the region wise, state wise average profit and sales and then extract information for east region.

# %%
east = pd.DataFrame(read.groupby(["Region","State"])[["Profit","Sales"]].mean())

# %%
temp = east.reset_index()

# %%
temp[temp["Region"]=="East"]
# Out:
#    Region          State     Profit       Sales
# 13   East    Connecticut  42.823071  163.223866
# ..    ...            ...        ...         ...
# 26   East  West Virginia  46.480400  302.456000
#
# [14 rows x 4 columns]

# %%
ex = read["Ship_Date"]

# %%
dt = pd.DatetimeIndex(ex)

# %%
x= dt[:49]

# %%
temp.reset_index()
# Out:
#     index   Region     State      Profit       Sales
# 0       0  Central  Illinois  -25.625787   162.93923
# ..    ...      ...       ...         ...         ...
# 48     48     West   Wyoming  100.196000  1603.13600
#
# [49 rows x 5 columns]

# %%
temp.index=x

# %%
temp
# Out:
#              Region     State      Profit       Sales
# Ship_Date
# 2016-11-11  Central  Illinois  -25.625787   162.93923
# ...             ...       ...         ...         ...
# 2016-06-25     West   Wyoming  100.196000  1603.13600
#
# [49 rows x 4 columns]

# %% [markdown]
# # 30. Find all record for furniture delivered in Texas

# %%
read[(read["Category"]=='Furniture') & (read["State"]=="Texas")]
# Out:
#            no       order__id Order_Date  Ship_Date    Ship_Mode Customer_ID  \
# 1936     37.0  CA-2016-117590 2016-12-08 2016-12-10  First Class    GH-14485
# ...       ...             ...        ...        ...          ...         ...
# 11862  9963.0  CA-2015-168088 2015-03-19 2015-03-22  First Class    CM-12655
#
#           Customer_Name      Segment        Country        City  ...  \
# 1936          Gene Hale    Corporate  United States  Richardson  ...
# ...                 ...          ...            ...         ...  ...
# 11862  Corinna Mitchell  Home Office  United States     Houston  ...
#
#       Postal_Code   Region       Product_ID   Category Sub-Category  \
# 1936        75080  Central  FUR-FU-10003664  Furniture  Furnishings
# ...           ...      ...              ...        ...          ...
# 11862       77041  Central  FUR-BO-10004218  Furniture    Bookcases
#
#                                             Product_Name     Sales  Quantity  \
# ...

# %%
read["City"].unique()
# Out:
# array(['Henderson', 'Los Angeles', 'Fort Lauderdale', 'Concord',
#        'Seattle', 'Fort Worth', 'Madison', 'West Jordan', 'San Francisco',
#        'Fremont', 'Philadelphia', 'Orem', 'Houston', 'Richardson',
#        'Naperville', 'Melbourne', 'Eagan', 'Westland', 'Dover',
#        'New Albany', 'New York City', 'Troy', 'Chicago', 'Gilbert',
#        'Springfield', 'Jackson', 'Memphis', 'Decatur', 'Durham',
#        'Columbia', 'Rochester', 'Minneapolis', 'Portland', 'Saint Paul',
#        'Aurora', 'Charlotte', 'Orland Park', 'Urbandale', 'Columbus',
#        'Bristol', 'Wilmington', 'Bloomington', 'Phoenix', 'Roseville',
#        'Independence', 'Pasadena', 'Newark', 'Franklin', 'Scottsdale',
#        'San Jose', 'Edmond', 'Carlsbad', 'San Antonio', 'Monroe',
#        'Fairfield', 'Grand Prairie', 'Redlands', 'Hamilton', 'Westfield',
#        'Akron', 'Denver', 'Dallas', 'Whittier', 'Saginaw', 'Medina',
#        'Dublin', 'Detroit', 'Tampa', 'Santa Clara', 'Lakeville',
# ...
