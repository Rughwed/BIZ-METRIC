# %%
import matplotlib.pyplot as plt
import plotly.express as px
import pandas as pd
import numpy as np
from log import log

# %%
sup = pd.read_excel('Superstore.xls',engine='xlrd')
sup.head(3)
# Out:
#     no       order _id Order Date  Ship Date     Ship Mode Customer ID  \
# 0  NaN             NaN 2016-11-08 2016-11-11  Second Class    CG-12520
# 1  2.0  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 2  3.0  CA-2016-138688 2016-06-12 2016-06-16  Second Class    DV-13045
#
#      Customer Name    Segment        Country         City  ... Postal Code  \
# 0      Claire Gute   Consumer  United States    Henderson  ...       42420
# 1      Claire Gute   Consumer  United States    Henderson  ...       42420
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  ...       90036
#
#    Region       Product ID         Category Sub-Category  \
# 0   South  FUR-BO-10001798        Furniture    Bookcases
# 1   South  FUR-CH-10000454        Furniture       Chairs
# 2    West  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# ...

# %%
category = sup[["Category","State","Quantity"]]
type(category)
temp = category[:10]

# %%
temp
# Out:
#           Category       State  Quantity
# 0        Furniture    Kentucky         2
# 1        Furniture    Kentucky         3
# 2  Office Supplies  California         2
# 3        Furniture     Florida         5
# 4  Office Supplies     Florida         2
# 5        Furniture  California         7
# 6  Office Supplies  California         4
# 7       Technology  California         6
# 8  Office Supplies  California         3
# 9  Office Supplies  California         5

# %%
len(category["State"].unique())
# Out:
# 49

# %%
px.bar(category,x="State",color="Category",title="my graph").update_layout(title_font_style='italic',title_font_color='Green',title_font_family='Arial').update_traces(marker_line_width=0)

# %%
px.bar(sup,x="Region",y="Profit",color="Category").update_traces(marker_line_width=0)

# %%
x = px.bar(sup,x="Category",y="Sales",color='Region').update_traces(marker_line_width=0)
x.show()

# %%
a = log("new")

# %%
a.info("Graph made")
# Out:
# INFO:mylogger:Graph made

# %%
sup.head(3)
# Out:
#     no       order _id Order Date  Ship Date     Ship Mode Customer ID  \
# 0  NaN             NaN 2016-11-08 2016-11-11  Second Class    CG-12520
# 1  2.0  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 2  3.0  CA-2016-138688 2016-06-12 2016-06-16  Second Class    DV-13045
#
#      Customer Name    Segment        Country         City  ... Postal Code  \
# 0      Claire Gute   Consumer  United States    Henderson  ...       42420
# 1      Claire Gute   Consumer  United States    Henderson  ...       42420
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  ...       90036
#
#    Region       Product ID         Category Sub-Category  \
# 0   South  FUR-BO-10001798        Furniture    Bookcases
# 1   South  FUR-CH-10000454        Furniture       Chairs
# 2    West  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# ...

# %%
import datetime as dt

# %%
dat = sup.groupby(sup["Order Date"].dt.month)["Sales"].sum()

# %%
mon= dat.reset_index()

# %%
mon
# Out:
#     Order Date        Sales
# 0            1   94924.8356
# 1            2   59751.2514
# 2            3  205005.4888
# 3            4  137762.1286
# 4            5  155028.8117
# 5            6  152718.6793
# 6            7  147238.0970
# 7            8  159044.0630
# 8            9  307649.9457
# 9           10  200322.9847
# 10          11  352461.0710
# 11          12  325293.5035

# %%
mon.rename(columns={"Order Date":"Month"},inplace=True)

# %%
mon
# Out:
#     Month        Sales
# 0       1   94924.8356
# 1       2   59751.2514
# 2       3  205005.4888
# 3       4  137762.1286
# 4       5  155028.8117
# 5       6  152718.6793
# 6       7  147238.0970
# 7       8  159044.0630
# 8       9  307649.9457
# 9      10  200322.9847
# 10     11  352461.0710
# 11     12  325293.5035

# %%
px.pie(mon,names="Month",values="Sales")
